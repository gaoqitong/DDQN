# %% [markdown]
# # R and Jupyter
# This notebook starts by demonstrating the integration capabilities of R with the Jupyter Project using some of the famous `demo(graphics)` command of R run inside a Jupyter notebook. Here the commands have been converted to markdown cells.
#
# We then look at which libraries and packages are installed, and make use of ggplot2 to demonstyrate some more extensive graphics, and calling a library that is not in the default set.
#
# ## Simple R demo
# Here is some code which illustrates some of the differences between R and S graphics capabilities. Note that colors are generally specified by a character string name (taken from the X11 rgb.txt file) and that line textures are given similarly. The parameter "bg" sets the background parameter for the plot and there is also an "fg" parameter which sets the foreground color.

# %%
require(datasets)
require(grDevices); 
require(graphics)

# %%
x <- stats::rnorm(50)
opar <- par(bg = "white")
plot(x, ann = FALSE, type = "n") +
abline(h = 0, col = gray(.90)) +
lines(x, col = "green4", lty = "dotted") +
points(x, bg = "limegreen", pch = 21) +
title(main = "Simple Use of Color In a Plot",
       xlab = "Just a Whisper of a Label",
       col.main = "blue", col.lab = gray(.8),
       cex.main = 1.2, cex.lab = 1.0, font.main = 4, font.lab = 3)
# Out:
# numeric(0)
# Plot with title "Simple Use of Color In a Plot"

# %% [markdown]
# ## A little color wheel.
#
# This code just plots equally spaced hues in
# a pie chart.

# %%
par(bg = "gray")

pie(rep(1,24), col = rainbow(24), radius = 0.9) +
title(main = "A Sample Color Wheel", cex.main = 1.4, font.main = 3) +
title(xlab = "(Use this as a test of monitor linearity)",
      cex.lab = 0.8, font.lab = 3)
# Out:
# numeric(0)
# Plot with title "A Sample Color Wheel"

# %% [markdown]
# ## A scatterplot matrix
# The good old Iris data (yet again)

# %%
pairs(iris[1:4], main="Edgar Anderson's Iris Data", pch=21,
       bg = c("red", "green3", "blue")[unclass(iris$Species)])
# Out:
# plot without title

# %% [markdown]
# ## Packages and libraries
# R can be extended with packages, and for your convenience a number of them are already installed in this notebook server. To list the installed packages we can issue the R command
# ```R
# rownames(installed.packages())
# ```

# %%
rownames(installed.packages())
# Out:
#   [1] "BH"            "BradleyTerry2" "DBI"           "IRdisplay"
#   [5] "IRkernel"      "KernSmooth"    "MASS"          "Matrix"
#   [9] "MatrixModels"  "R6"            "RColorBrewer"  "RCurl"
#  [13] "RSQLite"       "Rcpp"          "RcppArmadillo" "RcppEigen"
#  [17] "SparseM"       "assertthat"    "base"          "base64enc"
#  [21] "bitops"        "boot"          "brew"          "brglm"
#  [25] "caTools"       "car"           "caret"         "class"
#  [29] "cluster"       "codetools"     "colorspace"    "compiler"
#  [33] "curl"          "datasets"      "devtools"      "dichromat"
#  [37] "digest"        "dplyr"         "evaluate"      "foreach"
#  [41] "forecast"      "foreign"       "formatR"       "fracdiff"
#  [45] "ggplot2"       "git2r"         "grDevices"     "graphics"
#  [49] "grid"          "gtable"        "gtools"        "highr"
#  [53] "htmltools"     "httpuv"        "httr"          "iterators"
#  [57] "jsonlite"      "knitr"         "labeling"      "lattice"
# ...

# %% [markdown]
# While packages are installed, they may not be currently in use. To see which packages are loaded by default, use the command
# ```R
# getOption("defaultPackages")
# ```

# %%
 getOption("defaultPackages")
# Out:
# [1] "datasets"  "utils"     "grDevices" "graphics"  "stats"     "methods"

# %% [markdown]
# ## Using the ggplot2 package
#
# Suppose you found some exaples of using the ggplot2 package and want to try them. TO do this, we will firrst need to tell R to load the package with the command
# ```R
# library(ggplot2)
# ```

# %%
library(ggplot2)

# %% [markdown]
# Now that the ggplot 2 package is loaded, we can use it to run some of the example we found.
# For instance, the command
# ```R
# qplot(Sepal.Length, Petal.Length, data = iris, color = Species)
# ```
# creates a plot of sepal vs. petal length

# %%
qplot(Sepal.Length, Petal.Length, data = iris, color = Species)
# Out:
# plot without title

# %% [markdown]
# The plot was generated from the iris dataset that comes with R. We can look at the first part of that dataset with the command
# ```R
# head(iris)
# ```

# %%
head(iris)
# Out:
#   Sepal.Length Sepal.Width Petal.Length Petal.Width Species
# 1          5.1         3.5          1.4         0.2  setosa
# 2          4.9         3.0          1.4         0.2  setosa
# 3          4.7         3.2          1.3         0.2  setosa
# 4          4.6         3.1          1.5         0.2  setosa
# 5          5.0         3.6          1.4         0.2  setosa
# 6          5.4         3.9          1.7         0.4  setosa

# %% [markdown]
# Another dataset is the diamonds data. We can plot a sample of 1000 rows of the diamonds data with two commands:
# ```R
# dsamp <- diamonds[sample(nrow(diamonds), 1000), ]
# (d <- qplot(carat, price, data=dsamp, colour=clarity))
# ```

# %%
dsamp <- diamonds[sample(nrow(diamonds), 1000), ]
(d <- qplot(carat, price, data=dsamp, colour=clarity))
# Out:
# plot without title

# %% [markdown]
# You can also do interesting things with ggplot2, like vary the size of the
# markers base don the data. For example, make the size of the markers proportional to the petal width with this command:
# ```R
# qplot(Sepal.Length, Petal.Length, data = iris, color = Species, size = Petal.Width)
# # We see that Iris setosa flowers have the narrowest petals.
# ```

# %%
qplot(Sepal.Length, Petal.Length, data = iris, color = Species, size = Petal.Width)
# Out:
# plot without title

# %% [markdown]
# ## Advanced topics
#
# Another way of getting a list of installed packages is the command
# ```R
# installed.packages()
# ```

# %%
installed.packages()
# Out:
#               Package         LibPath                    Version       Priority
# BH            "BH"            "/opt/conda/lib/R/library" "1.58.0-1"    NA
# BradleyTerry2 "BradleyTerry2" "/opt/conda/lib/R/library" "1.0-6"       NA
# DBI           "DBI"           "/opt/conda/lib/R/library" "0.3.1"       NA
# IRdisplay     "IRdisplay"     "/opt/conda/lib/R/library" "0.3"         NA
# IRkernel      "IRkernel"      "/opt/conda/lib/R/library" "0.4"         NA
# KernSmooth    "KernSmooth"    "/opt/conda/lib/R/library" "2.23-15"     NA
# MASS          "MASS"          "/opt/conda/lib/R/library" "7.3-44"      NA
# Matrix        "Matrix"        "/opt/conda/lib/R/library" "1.2-2"       NA
# MatrixModels  "MatrixModels"  "/opt/conda/lib/R/library" "0.4-1"       NA
# R6            "R6"            "/opt/conda/lib/R/library" "2.1.1"       NA
# RColorBrewer  "RColorBrewer"  "/opt/conda/lib/R/library" "1.1-2"       NA
# RCurl         "RCurl"         "/opt/conda/lib/R/library" "1.95-4.7"    NA
# ...
